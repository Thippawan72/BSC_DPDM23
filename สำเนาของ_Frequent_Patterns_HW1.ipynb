# %% [markdown]
# <a href="https://colab.research.google.com/github/Thippawan72/BSC_DPDM23/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Frequent_Patterns_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # กลุ่ม ช่วยด้วย
# ### สมาชิก
#         - นางสาวทิพย์วัลย์ สุโพธิ์                 รหัส 643020062-6        สไลด์ + present
#         - นางสาวศดานันท์ ทรัพย์มีมหาศาล    รหัส 643021272-0        สไลด์ + present
#         - นางสาวสุชานาถ พิลาภ                  รหัส 643021276-2        สไลด์ + present
#         - นางสาวอิงอร พลพาล                    รหัส 643021279-6        Coding + present

# %% [markdown]
# สไลด์
# https://drive.google.com/file/d/1DRoCRGPNx_HteuV6oekoBAz36JpcOqEZ/view?fbclid=IwAR13pYHMsqH1ATlOtOItimKVpmEvLP4z1PEpxgPbEIKK4Pu76m7R9Jhdsdg

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/bsc_dpdm23_data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv(os.path.join(path,'/content/drive/MyDrive/BSC_DPDM23_Data/reduced_marketbasket.csv'),encoding='latin-1')
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# !pip install apyori  #โหลดเพื่อทำ Association Rule

# %%
from apyori import apriori

# %% [markdown]
# # HW1 หา Frequent Item Set และ Association Rules
#
# * ของช่วงเวลา Chrhistmas & New Year (1 Dec - 31 Dec)
# * ของประเทศในทวีป Europe
# * ของช่วงเวลาตรุษจีน ในทวีป Asia (15 Jan - 15 Feb)
# * ของช่วงเวลา Chrhistmas & New Year ในทวีป Europe (1 Dec - 31 Dec)
# * ของวันวาเลนไทน์
# * โดยจัดกลุ่มตามประเทศ + เดือน (groupby ประเทศกับเดือน)

# %% [markdown]
# ### จัดการวันที่

# %%
import datetime

# %%
data['InvoiceDate']
# Out:
# 0         12/01/2010 08:26
# 1         12/01/2010 08:26
# 2         12/01/2010 08:26
# 3         12/01/2010 08:26
# 4         12/01/2010 08:26
#                 ...
# 541904    12/09/2011 12:50
# 541905    12/09/2011 12:50
# 541906    12/09/2011 12:50
# 541907    12/09/2011 12:50
# 541908    12/09/2011 12:50
# Name: InvoiceDate, Length: 541909, dtype: object

# %%
# แปลงคอลัมน์ให้เป็น datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
#เปลี่ยนรูปแบบให้เป็น เดือน / วัน / ปี
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], format='%m/%d/%y')

# %%
# สร้างคอลัมน์ 'Date' โดยดึงข้อมูลเฉพาะวันที่
data['Date'] = data['InvoiceDate'].dt.date
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date
# ...

# %%
data['month'] = data['InvoiceDate'].dt.month

# %%
data['day'] = data['InvoiceDate'].dt.day

# %% [markdown]
# ## ฟังก์ชันที่หาว่าสินค้านั้นคืออะไร

# %%
def finditem(x,y) :
  L=set(data[(data['StockCode']==x)|(data['StockCode']==y)]['Description'])
  return L

# %% [markdown]
# # ข้อ 1 หาข้อมูลของช่วงเวลา Chrhistmas & New Year (1 Dec - 31 Dec)

# %%
# ดูช่วงเวลาคริสต์มาสกับปีใหม่
Christm_Newy = data[data['month']==12]
Christm_Newy
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
# แปลง data  ให้อยู่ในรูปแบบ Transaction data

trans_Christm_Newy = Christm_Newy.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
# หาความถี่ของสินค้าที่ถูกซื้อซ้ำๆกันในช่วงเวลาคริสต์มาสกับปีใหม่ โดยมีค่า min support คือ 8%
frequentItemsets= list(apriori(trans_Christm_Newy,min_support = 0.08))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22086'}), support=0.09243421052631579, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086'}), confidence=0.09243421052631579, lift=1.0)]),
#  RelationRecord(items=frozenset({'22423'}), support=0.08223684210526316, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08223684210526316, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.09769736842105263, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.09769736842105263, lift=1.0)])]

# %% [markdown]
# [RelationRecord(items=frozenset({'22086'}), support=0.09243421052631579, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086'}), confidence=0.09243421052631579, lift=1.0)]),
#
#  RelationRecord(items=frozenset({'22423'}), support=0.08223684210526316, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08223684210526316, lift=1.0)]),
#
#  RelationRecord(items=frozenset({'85123A'}), support=0.09769736842105263, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.09769736842105263, lift=1.0)])]

# %%
# จำนวนสินค้า
len(frequentItemsets)
# Out:
# 3

# %%
# หาสินค้าที่ถูกซื้อซ้ำจาก trans_Christm_Newy โดยกำหนดค่า min_sup = 0.045  และเช็คว่ามีสินค้ามากกว่า 1 ไอเท็มใน set นั้นหรือไม่

min_sup = 0.045

frequentItem_CN = list(apriori(trans_Christm_Newy,min_support = min_sup))
for i in frequentItem_CN:
    if i[0].__len__()>1:
        print('yes')
        print(i)
# Out:
# yes
# RelationRecord(items=frozenset({'22086', '22910'}), support=0.047697368421052634, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22086', '22910'}), confidence=0.047697368421052634, lift=1.0), OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5160142348754448, lift=7.195794834960331), OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6651376146788991, lift=7.195794834960332)])

# %% [markdown]
# yes
# RelationRecord(items=frozenset({'22910', '22086'}), support=0.047697368421052634,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22910', '22086'}), confidence=0.047697368421052634, lift=1.0),
#
# OrderedStatistic(items_base=frozenset({'22086'}), items_add=frozenset({'22910'}), confidence=0.5160142348754448, lift=7.195794834960331),
#
# OrderedStatistic(items_base=frozenset({'22910'}), items_add=frozenset({'22086'}), confidence=0.6651376146788991, lift=7.195794834960332)])

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22910') | (data['StockCode']=='22086')]['Description'])
# Out:
# {"PAPER CHAIN KIT 50'S CHRISTMAS ", 'PAPER CHAIN KIT VINTAGE CHRISTMAS'}

# %% [markdown]
# # ข้อ 2 หาข้อมูลของประเทศในทวีป Europe

# %%
#แยกประเทศที่อยู่ในทวีปยุโรป

Europe = [
    'Austria', 'Belgium', 'Channel Islands','Cyprus', 'Czech Republic', 'Denmark', 'EIRE',
    'European Community', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Italy',
    'Lithuania', 'Malta', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden',
    'Switzerland', 'United Kingdom'
]

# %%
EU_data = data[data['Country']==""]
for i in range(len(Europe)):
  x = data[data['Country']==Europe[i]]
  EU_data=pd.concat([x,EU_data])
EU_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 536964    581232   15056BL              EDWARDIAN PARASOL BLACK        24
# 536965    581232    15056P               EDWARDIAN PARASOL PINK        12
# 536966    581232     22059        CERAMIC STRAWBERRY DESIGN MUG        24
# 536967    581232     22646   CERAMIC STRAWBERRY CAKE MONEY BANK        36
# 536968    581232      POST                              POSTAGE         4
#
#                InvoiceDate  UnitPrice  CustomerID         Country        Date  \
# ...

# %%
# แปลง data  ให้อยู่ในรูปแบบ Transaction data

transactionsEU = EU_data.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
# หาความถี่ของสินค้าที่ถูกซื้อซ้ำๆกันในทวีปยุโรป โดยมีค่า min support คือ 5%

frequentItemsetsEU = list(apriori(transactionsEU,min_support = 0.05))
frequentItemsetsEU
# Out:
# [RelationRecord(items=frozenset({'20725'}), support=0.06187089502934204, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20725'}), confidence=0.06187089502934204, lift=1.0)]),
#  RelationRecord(items=frozenset({'20727'}), support=0.05009521588745094, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'20727'}), confidence=0.05009521588745094, lift=1.0)]),
#  RelationRecord(items=frozenset({'21212'}), support=0.05149430647856671, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'21212'}), confidence=0.05149430647856671, lift=1.0)]),
#  RelationRecord(items=frozenset({'22197'}), support=0.05584703276203801, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22197'}), confidence=0.05584703276203801, lift=1.0)]),
# ...

# %%
# จำนวนสินค้า
len(frequentItemsetsEU)
# Out:
# 11

# %%
# หาสินค้าที่ถูกซื้อซ้ำบ่อยในทวีปยุโรป โดยกำหนดค่า min_sup = 0.07  และเช็คว่ามีสินค้ามากกว่า 1 ไอเท็มใน set นั้นหรือไม่

min_sup = 0.03

frequentItem_EU = list(apriori(transactionsEU,min_support = min_sup))
for i in frequentItem_EU:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItem_EU
# Out:
# yes
# RelationRecord(items=frozenset({'22386', '85099B'}), support=0.03233453810578679, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22386', '85099B'}), confidence=0.03233453810578679, lift=1.0), OrderedStatistic(items_base=frozenset({'22386'}), items_add=frozenset({'85099B'}), confidence=0.6775244299674267, lift=8.203944050584402), OrderedStatistic(items_base=frozenset({'85099B'}), items_add=frozenset({'22386'}), confidence=0.39152941176470585, lift=8.203944050584402)])
# yes
# ...

# %% [markdown]
# output
# [RelationRecord(items=frozenset({'22423'}), support=0.08355679919163654,
#
# ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08355679919163654, lift=1.0)]),
#
# RelationRecord(items=frozenset({'85099B'}), support=0.0825852085033617, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.0825852085033617, lift=1.0)]),
#
# RelationRecord(items=frozenset({'85123A'}), support=0.08713225292448797, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08713225292448797, lift=1.0)])]

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22423')| (data['StockCode']=='85123A')]['Description'])
# Out:
# {'?',
#  'CREAM HANGING HEART T-LIGHT HOLDER',
#  'REGENCY CAKESTAND 3 TIER',
#  'WHITE HANGING HEART T-LIGHT HOLDER',
#  'damages',
#  'faulty',
#  'wrongly marked carton 22804'}

# %% [markdown]
# #ข้อ3 หาข้อมูลของช่วงเวลา ตรุษจีน ในทวีป Asia (15 jan - 15 Feb)

# %% [markdown]
# ### จัดการข้อมูลในช่วงตรุษจีนของทวีปเอเชีย

# %%
Asia = ['Hong Kong','Bahrain','Israel','Japan','Lebanon','Saudi Arabia','Singapore','United Arab Emirates']

# %%
ASIA_data = data[data['Country']==""]
for i in range(len(Asia)):
  x = data[data['Country']==Asia[i]]
  ASIA_data=pd.concat([x,ASIA_data])
ASIA_data
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 89570     543911     21485    RETROSPOT HEART HOT WATER BOTTLE         6
# 89571     543911     48138                  DOORMAT UNION FLAG         2
# 89572     543911     85150       LADIES & GENTLEMEN METAL SIGN        24
# 89573     543911     82552                 WASHROOM METAL SIGN        24
# 89574     543911     82551              LAUNDRY 15C METAL SIGN        12
# ...          ...       ...                                 ...       ...
# 423776    573154     22452        MEASURING TAPE BABUSHKA PINK        30
# 423777    573154     22492             MINI PAINT SET VINTAGE         36
# 423778    573154     23328  SET 6 SCHOOL MILK BOTTLES IN CRATE         8
# 465423   C576233         M                              Manual        -1
# 465424    576234         M                              Manual         1
#
#                InvoiceDate  UnitPrice  CustomerID               Country  \
# ...

# %%
As_data=ASIA_data[(ASIA_data['month']==1)]
As_data.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 70758    542102     21519   GIN & TONIC DIET GREETING CARD         72
# 70759    542102     22697   GREEN REGENCY TEACUP AND SAUCER         6
# 70760    542102     22699  ROSES REGENCY TEACUP AND SAUCER          6
# 70761    542102     22343    PARTY PIZZA DISH RED RETROSPOT        24
# 70762    542102     22344    PARTY PIZZA DISH PINK POLKADOT        24
#
#               InvoiceDate  UnitPrice  CustomerID    Country        Date  \
# 70758 2011-01-25 13:26:00       0.36     12744.0  Singapore  2011-01-25
# 70759 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70760 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70761 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
# 70762 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
#
#        month  day
# 70758      1   25
# 70759      1   25
# 70760      1   25
# 70761      1   25
# ...

# %%
As_data_d=As_data[(As_data['day']>=15)]
As_data_d.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 70758    542102     21519   GIN & TONIC DIET GREETING CARD         72
# 70759    542102     22697   GREEN REGENCY TEACUP AND SAUCER         6
# 70760    542102     22699  ROSES REGENCY TEACUP AND SAUCER          6
# 70761    542102     22343    PARTY PIZZA DISH RED RETROSPOT        24
# 70762    542102     22344    PARTY PIZZA DISH PINK POLKADOT        24
#
#               InvoiceDate  UnitPrice  CustomerID    Country        Date  \
# 70758 2011-01-25 13:26:00       0.36     12744.0  Singapore  2011-01-25
# 70759 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70760 2011-01-25 13:26:00       2.95     12744.0  Singapore  2011-01-25
# 70761 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
# 70762 2011-01-25 13:26:00       0.21     12744.0  Singapore  2011-01-25
#
#        month  day
# 70758      1   25
# 70759      1   25
# 70760      1   25
# 70761      1   25
# ...

# %%
As_data2=ASIA_data[(ASIA_data['month']==2)]
As_data2.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 89570    543911     21485  RETROSPOT HEART HOT WATER BOTTLE         6
# 89571    543911     48138                DOORMAT UNION FLAG         2
# 89572    543911     85150     LADIES & GENTLEMEN METAL SIGN        24
# 89573    543911     82552               WASHROOM METAL SIGN        24
# 89574    543911     82551            LAUNDRY 15C METAL SIGN        12
#
#               InvoiceDate  UnitPrice  CustomerID               Country  \
# 89570 2011-02-14 12:46:00       4.95     17829.0  United Arab Emirates
# 89571 2011-02-14 12:46:00       7.95     17829.0  United Arab Emirates
# 89572 2011-02-14 12:46:00       2.55     17829.0  United Arab Emirates
# 89573 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
# 89574 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
#
#              Date  month  day
# 89570  2011-02-14      2   14
# 89571  2011-02-14      2   14
# ...

# %%
As_data_d2=As_data2[(As_data2['day']<=15)]
As_data_d2.head()
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 89570    543911     21485  RETROSPOT HEART HOT WATER BOTTLE         6
# 89571    543911     48138                DOORMAT UNION FLAG         2
# 89572    543911     85150     LADIES & GENTLEMEN METAL SIGN        24
# 89573    543911     82552               WASHROOM METAL SIGN        24
# 89574    543911     82551            LAUNDRY 15C METAL SIGN        12
#
#               InvoiceDate  UnitPrice  CustomerID               Country  \
# 89570 2011-02-14 12:46:00       4.95     17829.0  United Arab Emirates
# 89571 2011-02-14 12:46:00       7.95     17829.0  United Arab Emirates
# 89572 2011-02-14 12:46:00       2.55     17829.0  United Arab Emirates
# 89573 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
# 89574 2011-02-14 12:46:00       1.45     17829.0  United Arab Emirates
#
#              Date  month  day
# 89570  2011-02-14      2   14
# 89571  2011-02-14      2   14
# ...

# %%
# รวมทั้ง 2 เดือนเข้าด้วยกัน ในช่วงตรุษจีน
Asia_data_chi=pd.concat([As_data_d,As_data_d2])
Asia_data_chi
# Out:
#       InvoiceNo StockCode                          Description  Quantity  \
# 70758    542102     21519      GIN & TONIC DIET GREETING CARD         72
# 70759    542102     22697      GREEN REGENCY TEACUP AND SAUCER         6
# 70760    542102     22699     ROSES REGENCY TEACUP AND SAUCER          6
# 70761    542102     22343       PARTY PIZZA DISH RED RETROSPOT        24
# 70762    542102     22344       PARTY PIZZA DISH PINK POLKADOT        24
# ...         ...       ...                                  ...       ...
# 85761    543518     21080  SET/20 RED RETROSPOT PAPER NAPKINS         96
# 85762    543518     21217        RED RETROSPOT ROUND CAKE TINS        24
# 85763    543518     21216     SET 3 RETROSPOT TEA,COFFEE,SUGAR        48
# 85764    543518     21980    PACK OF 12 RED RETROSPOT TISSUES         96
# 85765    543518     22333    RETROSPOT PARTY BAG + STICKER SET        96
#
#               InvoiceDate  UnitPrice  CustomerID    Country        Date  \
# ...

# %% [markdown]
# ### หาข้อมูล

# %%
# แปลง data  ให้อยู่ในรูปแบบ Transaction data
transactionsAsiaChi = Asia_data_chi.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup = 0.082
frequentItemsets_Asia= list(apriori(transactionsAsiaChi,min_support = min_sup))
for i in frequentItemsets_Asia:
    if i[0].__len__()>3:
        print('yes')
        print(i)
frequentItemsets_Asia

# %% [markdown]
# [RelationRecord(items=frozenset({'22423'}), support=0.08432400502104408, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08432400502104408, lift=1.0)]),
#
#  RelationRecord(items=frozenset({'85099B'}), support=0.0823303551650299, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.0823303551650299, lift=1.0)]),
#
#
#  RelationRecord(items=frozenset({'85123A'}), support=0.08993576017130621, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08993576017130621, lift=1.0)])]

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22423') | (data['StockCode']=='85099B')| (data['StockCode']=='85123A')]['Description'])

# %% [markdown]
# # ข้อ 4 ของช่วงเวลา Chrhistmas & New Year ในทวีป Europe (1 Dec - 31 Dec)

# %%
Europe = [
    'Austria', 'Belgium', 'Channel Islands','Cyprus', 'Czech Republic', 'Denmark', 'EIRE',
    'European Community', 'Finland', 'France', 'Germany', 'Greece', 'Iceland', 'Italy',
    'Lithuania', 'Malta', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain', 'Sweden',
    'Switzerland', 'United Kingdom'
]

# %%
EU_data = data[data['Country']==""]
for i in range(len(Europe)):
  x = data[data['Country']==Europe[i]]
  EU_data=pd.concat([x,EU_data])
EU_data

# %%
Eu_data=EU_data[(EU_data['month']==12)]
Eu_data.head()

# %%
Eu_data_d=Eu_data[(Eu_data['day']<=31)]
Eu_data_d.head()

# %% [markdown]
# ## หาข้อมูล

# %%
# แปลง data  ให้อยู่ในรูปแบบ Transaction data
transactionsEU_C_N = Eu_data_d.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
min_sup =0.08
frequentItemsetsEU= list(apriori(transactionsEU_C_N,min_support = min_sup))
for i in frequentItemsetsEU:
    if i[0].__len__()>3:
        print('yes')
        print(i)
frequentItemsetsEU

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22086')|(data['StockCode']=='22423')]['Description'])

# %% [markdown]
# # ข้อ 5 ของวันวาเลนไทน์ (14 Feb)

# %%
Valen_data = data[(data['month']==2)]
Valen_data

# %%
valen_day=Valen_data[Valen_data['day']==14]
valen_day

# %%
# จัดกลุ่มตาม transactions

transactions_valen = valen_day.groupby('InvoiceNo')['StockCode'].apply(list)

# %%
# นับจำนวนสินค้าในช่วงวาเลนไทน์

len(transactions_valen)

# %%
min_sup = 0.09
frequentItemsets_valen= list(apriori(transactions_valen,min_support = min_sup))
for i in frequentItemsets_valen:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_valen

# %% [markdown]
# # ข้อ 6 จัดกลุ่มตามประเทศ + เดือน โดยไม่มีเงื่อนไข

# %%
transactions_M_C = data.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_M_C

# %%
min_sup = 0.32
frequentItemsets_M_C = list(apriori(transactions_M_C,min_support = min_sup))
for i in frequentItemsets_M_C:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_M_C

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22326') | (data['StockCode']=='POST')]['Description'])

# %% [markdown]
# ##ข้อ 6.1 group by ตามเดือนและประเทศ ในช่วงเวลาคริสต์มาสและปีใหม่

# %%
transactions_C_N = Christm_Newy.groupby(['Country', 'month'])['StockCode'].apply(list)
transactions_C_N

# %%
min_sup =0.3
frequentItemsets_C_N = list(apriori(transactions_C_N,min_support = min_sup))
for i in frequentItemsets_C_N:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_C_N

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='POST')|(data['StockCode']=='20750')]['Description'])

# %% [markdown]
# ##ข้อ 6.2 group by ตามเดือนและประเทศ ในทวีปยุโรป

# %%
transactionsEU = EU_data.groupby(['Country', 'month'])['StockCode'].apply(list)

# %%
min_sup = 0.4
frequentItemsetsEU= list(apriori(transactionsEU,min_support = min_sup))
for i in frequentItemsetsEU:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsetsEU

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22326')|(data['StockCode']=='POST')]['Description'])

# %% [markdown]
# ##ข้อ 6.3 group by ตามเดือนและประเทศ ในช่วงเวลาตรุษจีนในทวีเอเชีย

# %%
transactionsAsia = Asia_data_chi.groupby(['Country', 'month'])['StockCode'].apply(list)

# %%
min_sup = 0.35
frequentItemsets_Asia= list(apriori(transactionsAsia,min_support = min_sup))
for i in frequentItemsets_Asia:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_Asia

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22326')|(data['StockCode']=='POST')]['Description'])

# %% [markdown]
# ## ข้อ 6.4  group by ตามเดือนและประเทศ ในช่วงคริสต์มาสและปีใหม่ในยุโรป

# %%
transactionsEU_C_N = EU_data.groupby(['Country', 'month'])['StockCode'].apply(list)

# %%
min_sup = 0.4
frequentItemsetsEU= list(apriori(transactionsEU_C_N,min_support = min_sup))
for i in frequentItemsetsEU:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsetsEU

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22326')|(data['StockCode']=='POST')]['Description'])

# %% [markdown]
# ## ข้อ 6.5  group by ตามเดือนและประเทศ ในช่วงวาเลนไทน์

# %%
transactions_va = va_data.groupby(['Country', 'month'])['StockCode'].apply(list)

# %%
min_sup = 0.08
frequentItemsets_valen= list(apriori(transactions_valen,min_support = min_sup))
for i in frequentItemsets_valen:
    if i[0].__len__()>1:
        print('yes')
        print(i)
frequentItemsets_valen

# %%
# ดูว่าสินค้านั้นคืออะไร

set(data[(data['StockCode']=='22722')|(data['StockCode']=='22720')]['Description'])
